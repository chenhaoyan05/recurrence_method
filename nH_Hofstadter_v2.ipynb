# %%
import mpmath
import numpy as np
import matplotlib.pyplot as plt
import time
import math

plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'

# Find the polynomial coefficients for triangle Hofstadter model
# with vector potential Ay=(p/q)*2pi*x and non-Hermitian term delta
# with momentum in y direction ky
def pk(p,q,delta,ky):
    # brute forcely calculate pk for k=1,2,3,4
    A = (mpmath.mpf(1) + delta)/(mpmath.mpf(1) - delta)
    B = (mpmath.mpf(1) - delta)/(mpmath.mpf(1) + delta)
    if q == 1:
        T = 2+A*mpmath.exp(1j*(3*mpmath.pi*(p/q)-ky))+B*mpmath.exp(-1j*(3*mpmath.pi*(p/q)-ky))
        V = mpmath.sqrt(A)*mpmath.exp(-1j*(2*mpmath.pi*(p/q)-ky))+ \
            mpmath.sqrt(B)*mpmath.exp(1j*(2*mpmath.pi*(p/q)-ky))
        poly = [1,-V]
        poly_init = [1,-V]
        return poly,T,poly_init
    elif q == 2:
        Tq = [0] * (q + 1)
        Vq = [0] * (q + 1)
        Vq[1] = mpmath.sqrt(A)*mpmath.exp(-1j*(2*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(2*mpmath.pi*(p/q)-ky))
        Vq[2] = mpmath.sqrt(A)*mpmath.exp(-1j*(4*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(4*mpmath.pi*(p/q)-ky))
        Tq[1] = 2 + A*mpmath.exp(1j*(3*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(3*mpmath.pi*(p/q)-ky))
        Tq[2] = 2 + A*mpmath.exp(1j*(5*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(5*mpmath.pi*(p/q)-ky))
        T = Tq[1]*Tq[2]
        poly = [1,-Vq[1]-Vq[2],-Tq[1]-Tq[2]+Vq[1]*Vq[2]]
        poly_init = [1,-Vq[1]-Vq[2],-Tq[1]+Vq[1]*Vq[2]]
        return poly,T,poly_init
    elif q == 3:
        Tq = [0] * (q + 1)
        Vq = [0] * (q + 1)
        Vq[1] = mpmath.sqrt(A)*mpmath.exp(-1j*(2*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(2*mpmath.pi*(p/q)-ky))
        Vq[2] = mpmath.sqrt(A)*mpmath.exp(-1j*(4*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(4*mpmath.pi*(p/q)-ky))
        Vq[3] = mpmath.sqrt(A)*mpmath.exp(-1j*(6*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(6*mpmath.pi*(p/q)-ky))
        Tq[1] = 2 + A*mpmath.exp(1j*(3*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(3*mpmath.pi*(p/q)-ky))
        Tq[2] = 2 + A*mpmath.exp(1j*(5*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(5*mpmath.pi*(p/q)-ky))
        Tq[3] = 2 + A*mpmath.exp(1j*(7*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(7*mpmath.pi*(p/q)-ky))
        T = Tq[1]*Tq[2]*Tq[3]
        poly = [1,-Vq[1]-Vq[2]-Vq[3],-Tq[1]-Tq[2]-Tq[3]+Vq[1]*Vq[2]+Vq[1]*Vq[3]+Vq[2]*Vq[3],Tq[1]*Vq[3]+Tq[2]*Vq[1]+Tq[3]*Vq[2]]
        poly_init = [1,-Vq[1]-Vq[2]-Vq[3],-Tq[1]-Tq[2]+Vq[1]*Vq[2]+Vq[1]*Vq[3]+Vq[2]*Vq[3],Tq[1]*Vq[3]+Tq[2]*Vq[1]-Vq[1]*Vq[2]*Vq[3]]
        return poly,T,poly_init
    elif q == 4:
        Tq = [0] * (q + 1)
        Vq = [0] * (q + 1)
        Vq[1] = mpmath.sqrt(A)*mpmath.exp(-1j*(2*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(2*mpmath.pi*(p/q)-ky))
        Vq[2] = mpmath.sqrt(A)*mpmath.exp(-1j*(4*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(4*mpmath.pi*(p/q)-ky))
        Vq[3] = mpmath.sqrt(A)*mpmath.exp(-1j*(6*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(6*mpmath.pi*(p/q)-ky))
        Vq[4] = mpmath.sqrt(A)*mpmath.exp(-1j*(8*mpmath.pi*(p/q)-ky))+ \
                mpmath.sqrt(B)*mpmath.exp(1j*(8*mpmath.pi*(p/q)-ky))
        Tq[1] = 2 + A*mpmath.exp(1j*(3*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(3*mpmath.pi*(p/q)-ky))
        Tq[2] = 2 + A*mpmath.exp(1j*(5*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(5*mpmath.pi*(p/q)-ky))
        Tq[3] = 2 + A*mpmath.exp(1j*(7*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(7*mpmath.pi*(p/q)-ky))
        Tq[4] = 2 + A*mpmath.exp(1j*(9*mpmath.pi*(p/q)-ky)) + \
                B*mpmath.exp(-1j*(9*mpmath.pi*(p/q)-ky))
        T = Tq[1]*Tq[2]*Tq[3]*Tq[4]
        poly = [mpmath.mpc(0)] * (q + 1)
        poly[0] = 1
        poly[1] = -Vq[1]-Vq[2]-Vq[3]-Vq[4]
        poly[2] = -Tq[1]-Tq[2]-Tq[3]-Tq[4]+Vq[1]*Vq[2]+Vq[1]*Vq[3]+Vq[1]*Vq[4]+Vq[2]*Vq[3]+Vq[2]*Vq[4]+Vq[3]*Vq[4]
        poly[3] = Tq[1]*(Vq[3]+Vq[4])+Tq[2]*(Vq[1]+Vq[4])+Tq[3]*(Vq[1]+Vq[2])+Tq[4]*(Vq[2]+Vq[3])-Vq[1]*Vq[2]*Vq[3]-Vq[1]*Vq[2]*Vq[4]-Vq[1]*Vq[3]*Vq[4]-Vq[2]*Vq[3]*Vq[4]
        poly[4] = Vq[1]*Vq[3]*Vq[2]*Vq[4]-Tq[1]*Vq[3]*Vq[4]-Tq[2]*Vq[1]*Vq[4]-Tq[3]*Vq[1]*Vq[2]-Tq[4]*Vq[2]*Vq[3]+Tq[1]*Tq[3]+Tq[2]*Tq[4]
        poly_init = [mpmath.mpc(0)] * (q + 1)
        poly_init[0] = 1
        poly_init[1] = -Vq[1]-Vq[2]-Vq[3]-Vq[4]
        poly_init[2] = -Tq[1]-Tq[2]-Tq[3]+Vq[1]*Vq[2]+Vq[1]*Vq[3]+Vq[2]*Vq[3]+Vq[1]*Vq[4]+Vq[2]*Vq[4]+Vq[3]*Vq[4]
        poly_init[3] = Tq[1]*(Vq[3]+Vq[4])+Tq[2]*(Vq[1]+Vq[4])+Tq[3]*(Vq[1]+Vq[2]) \
                       -Vq[1]*Vq[2]*Vq[3]-Vq[1]*Vq[2]*Vq[4]-Vq[1]*Vq[3]*Vq[4]-Vq[2]*Vq[3]*Vq[4]
        poly_init[4] = Tq[1]*Tq[3]-Tq[1]*Vq[3]*Vq[4]-Tq[2]*Vq[1]*Vq[4]-Tq[3]*Vq[1]*Vq[2]+Vq[1]*Vq[2]*Vq[3]*Vq[4]
        return poly,T,poly_init
    # for k >= 5 (k = q)
    else:
        Tq = [mpmath.mpf(0)] * (q + 1)
        Vq = [mpmath.mpf(0)] * (q + 1)
        for i in range(1,q+1):
            # store V_i and T_i
            Vq[i] = mpmath.sqrt(A)*mpmath.exp(-mpmath.mpc(0,1)*(mpmath.mpf(2)*mpmath.pi*(mpmath.mpf(p) / mpmath.mpf(q))*mpmath.mpf(i)-ky))+ \
                    mpmath.sqrt(B)*mpmath.exp(mpmath.mpc(0,1)*(mpmath.mpf(2)*mpmath.pi*(mpmath.mpf(p) / mpmath.mpf(q))*mpmath.mpf(i)-ky))
            Tq[i] = 2 + A*mpmath.exp(mpmath.mpc(0,1)*(mpmath.mpf(2)*mpmath.pi*(mpmath.mpf(p) / mpmath.mpf(q))*(mpmath.mpf(i)+mpmath.mpf('0.5'))-ky))+ \
                    B*mpmath.exp(-mpmath.mpc(0,1)*(mpmath.mpf(2)*mpmath.pi*(mpmath.mpf(p) / mpmath.mpf(q))*(mpmath.mpf(i)+mpmath.mpf('0.5'))-ky))
        # calculate coefficients of Delta_{1,k}
        Delta1 = mpmath.matrix(q+1,q+1)
        # initial condition Delta_{1,1} and Delta_{1,2}
        Delta1[1,1] = -Vq[1]
        Delta1[2,1] = -Vq[1]-Vq[2]
        Delta1[2,2] = Vq[1]*Vq[2]-Tq[1]
        # recursively calculate coefficients of Delta_{1,i} until i=k
        for i in range(3,q+1):
            Delta1[i,1] = Delta1[i-1,1] - Vq[i]
            Delta1[i,2] = Delta1[i-1,2] - Vq[i]*Delta1[i-1,1] - Tq[i-1]
            for k in range(3,i):
                Delta1[i,k] = Delta1[i-1,k] - Vq[i]*Delta1[i-1,k-1] - Tq[i-1]*Delta1[i-2,k-2]
            Delta1[i,i] = -Vq[i]*Delta1[i-1,i-1] - Tq[i-1]*Delta1[i-2,i-2]
        # calculate coefficients of Delta_{2,k-1}
        Delta2 = mpmath.matrix(q+1,q+1)
        # initial condition Delta_{2,2} and Delta_{2,3}
        Delta2[2,1] = -Vq[2]
        Delta2[3,1] = -Vq[2]-Vq[3]
        Delta2[3,2] = Vq[2]*Vq[3]-Tq[2]
        # recursively calculate coefficients of Delta_{2,i} until i=k-1
        for i in range(4,q):
            Delta2[i,1] = Delta2[i-1,1] - Vq[i]
            Delta2[i,2] = Delta2[i-1,2] - Vq[i]*Delta2[i-1,1] - Tq[i-1]
            for k in range(3,i-1):
                Delta2[i,k] = Delta2[i-1,k] - Vq[i]*Delta2[i-1,k-1] - Tq[i-1]*Delta2[i-2,k-2]
            Delta2[i,i-1] = -Vq[i]*Delta2[i-1,i-2] - Tq[i-1]*Delta2[i-2,i-3]
        # T=T1*T2*...*Tq
        T = 1
        for i in range(1,q+1):
            T = T*Tq[i]
        # poly1 = Delta_{1,q}
        poly1 = [1] + list(Delta1[q,1:])
        # poly2 = -Tq*Delta_{2,q-1}
        poly2 = [0,0] + [-Tq[q]] + [x * (-Tq[q]) for x in list(Delta2[q-1,1:q-1])]
        # pk = Delta_{1,q} - Tq*Delta_{2,q-1}
        poly = [x + y for x,y in zip(poly1,poly2)]
        # return pk,T,Dk=Delta_{1,q}
        return poly,T,poly1
    
# multiply of two polynomials with degree q
def polymul(poly1,poly2,q):
    poly = [mpmath.mpf(0)] * (2 * q + 1)
    for i in range(0, q + 1):
        for j in range(0, q + 1):
            poly[i + j] += poly1[i] * poly2[j]
    return poly

# use fraction with lower q to approxiamte i/100. i,e, 19/100->4/21
def find_nearest_fraction(x, max_denominator=80):
    min_diff = float('inf')
    best_fraction = None
    
    for q in range(1, max_denominator + 1):
        p = round(x * q)
        diff = abs(x - p / q)
        if diff < min_diff:
            min_diff = diff
            best_fraction = (p, q)
    
    return best_fraction

# compute nH_Hofstadter_butterfly
# return p/q, real spectrum and imaginary spectrum
def nH_Hofstadter(delta,ky,Q=150,N=600,dps=80):
    start_time = time.time()
    mpmath.mp.dps = dps # set the precision dps=70
    nphi_array = [0] * int(2 * N * Q)
    real_spectrum_array = [0] * int(2 * N * Q)
    imag_spectrum_array = [0] * int(2 * N * Q)

    eigct = 0 # number of eigvals
    
    for i in range(0,Q):
        start_time_i = time.time()
        print(f'iteration:{i}',end=' ')
        mpmath.mp.dps = 80 # set the low precision
        # bulk OBC spectrum by solving pk(E)=2sqrt(T)sin(theta)
        if i in [1,199]: # find_nearest_fraction not work well for these i
            gcd = math.gcd(i,Q)
            p = round(i / gcd)
            q = round(Q / gcd)
        else:
            # use fraction with lower q to approxiamte i/100
            p,q = find_nearest_fraction(i/Q)
        poly,T,poly_init = pk(p,q,delta,ky) # solve pk,T,Dk
        nn = int(round(N / q)) # number of theta choices
        t = 2*mpmath.sqrt(T) # t = 2sqrt(T)
        poly_temp = poly[:] # 不能使用poly_temp = poly，这样poly_temp和poly指向同一个对象，修改poly_temp会同时修改poly
        for j in range(0,nn):
            chebyshev_root = mpmath.cos((2 * j + 1) * mpmath.pi / (2 * nn))
            poly_temp[q] = poly[q] - t*chebyshev_root
            # solve pk(E)=2sqrt(T)sin(theta) for sin(theta) = chebyshev_root
            roots = mpmath.polyroots(poly_temp,maxsteps=1000,extraprec=300)
            # store the real part and imaginary part of spectrum
            roots_real = [x.real for x in roots]
            roots_imag = [x.imag for x in roots]
            nphi_array[eigct: eigct+q+1] = [p/q] * q
            real_spectrum_array[eigct: eigct+q+1] = roots_real
            imag_spectrum_array[eigct: eigct+q+1] = roots_imag
            eigct = eigct + q
        # avoid to calculate edge OBC spectrum if q is large
        if q < 80 and p > 0:
            # edge OBC spectrum
            mpmath.mp.dps = 100 # raise the precision since polynomial degree is higher
            Dk_square = polymul(poly_init,poly_init,q) # Dk*Dk
            Dkpk = polymul(poly_init,poly,q) # Dk*pk
            poly_edge = [x - y for x,y in zip(Dk_square,Dkpk)] # Dk*Dk-Dk*pk
            # drop the terms with zero coefficients
            index = 0
            while mpmath.fabs(poly_edge[index]) < 0.000001:
                index = index + 1
            poly_edge = poly_edge[index:]
            # poly_edge = Dk*Dk-Dk*pk+T
            poly_edge[-1] = poly_edge[-1] + T
            # solve Dk*Dk-Dk*pk+T=0
            roots_edge = mpmath.polyroots(poly_edge,maxsteps=1000,extraprec=300)
            # Check whether roots of Dk*Dk-Dk*pk+T satisfy the following condition:
            # Dk=x_+(E), |x_+(E)|<|x_-(E)| or Dk=x_-(E), |x_-(E)|<|x_+(E)|
            # where x_\pm(E)=(pk(E)^2\pm\sqrt(pk(E)^2-4*T))
            for root in roots_edge:
                pk_root_value = mpmath.polyval(poly,root) # pk(E)
                Dk_root_value = mpmath.polyval(poly_init,root) # Dk(E)
                # x_+(E)
                x1 = mpmath.mpf('0.5')*(pk_root_value + mpmath.sqrt(pk_root_value**2 - mpmath.mpf(4)*T))
                # x_-(E)
                x2 = pk_root_value - x1
                # if Dk(E)=x_+(E) and |x_+(E)|<|x_-(E)|
                if mpmath.fabs(Dk_root_value - x1) < 0.0001 and mpmath.fabs(x1) < mpmath.fabs(x2):
                    nphi_array[eigct] = p/q
                    real_spectrum_array[eigct] = root.real
                    imag_spectrum_array[eigct] = root.imag
                    eigct = eigct + 1
                # if Dk(E)=x_-(E) and |x_-(E)|<|x_+(E)|
                elif mpmath.fabs(Dk_root_value - x2) < 0.0001 and mpmath.fabs(x2) < mpmath.fabs(x1):
                    nphi_array[eigct] = p/q
                    real_spectrum_array[eigct] = root.real
                    imag_spectrum_array[eigct] = root.imag
                    eigct = eigct + 1
                    
        end_time_i = time.time()
        print(f"time consuming: {end_time_i-start_time_i}")
    
    nphi_array = nphi_array[0:eigct]
    real_spectrum_array = real_spectrum_array[0:eigct]
    imag_spectrum_array = imag_spectrum_array[0:eigct]
    end_time = time.time()
    print(f"total time consuming: {end_time - start_time}")
    return nphi_array,real_spectrum_array,imag_spectrum_array

# %%
nphi_array,real_spectrum_array,imag_spectrum_array=nH_Hofstadter(mpmath.mpf('0.2'),mpmath.mpf('0')*mpmath.pi)
# Out:
# iteration:0 time consuming: 0.15005993843078613
# iteration:1 time consuming: 916.6488711833954
# iteration:2 time consuming: 134.36826181411743
# iteration:3 time consuming: 171.43249320983887
# iteration:4 time consuming: 84.58661580085754
# iteration:5 time consuming: 50.329405069351196
# iteration:6 time consuming: 252.66066789627075
# iteration:7 time consuming: 170.64021825790405
# iteration:8 time consuming: 17.154495239257812
# iteration:9 time consuming: 268.6541221141815
# iteration:10 time consuming: 12.18859052658081
# iteration:11 time consuming: 345.02135276794434
# iteration:12 time consuming: 122.97458100318909
# iteration:13 time consuming: 415.27521800994873
# iteration:14 time consuming: 183.5723056793213
# iteration:15 time consuming: 73.88335537910461
# iteration:16 time consuming: 24.460365533828735
# iteration:17 time consuming: 112.69148445129395
# iteration:18 time consuming: 426.99285078048706
# iteration:19 time consuming: 17.01638436317444
# iteration:20 time consuming: 4.425862789154053
# iteration:21 time consuming: 13.93499207496643
# iteration:22 time consuming: 350.9991638660431
# iteration:23 time consuming: 224.4795627593994
# iteration:24 time consuming: 26.946069478988647
# iteration:25 time consuming: 2.9780147075653076
# iteration:26 time consuming: 415.0955047607422
# iteration:27 time consuming: 64.9357681274414
# iteration:28 time consuming: 128.54620504379272
# iteration:29 time consuming: 303.492977142334
# iteration:30 time consuming: 16.114410638809204
# iteration:31 time consuming: 287.3244528770447
# iteration:32 time consuming: 27.34562110900879
# iteration:33 time consuming: 405.1454212665558
# iteration:34 time consuming: 139.93522572517395
# iteration:35 time consuming: 72.40190124511719
# iteration:36 time consuming: 128.37728095054626
# iteration:37 time consuming: 27.315369844436646
# iteration:38 time consuming: 430.56249022483826
# iteration:39 time consuming: 78.53152847290039
# iteration:40 time consuming: 1.2792863845825195
# iteration:41 time consuming: 4882.476223945618
# iteration:42 time consuming: 222.40405702590942
# iteration:43 time consuming: 423.1699447631836
# iteration:44 time consuming: 121.46015787124634
# iteration:45 time consuming: 74.54523754119873
# iteration:46 time consuming: 336.42661929130554
# iteration:47 time consuming: 10.414842367172241
# iteration:48 time consuming: 23.382132053375244
# iteration:49 time consuming: 105.24586153030396
# iteration:50 time consuming: 0.9947555065155029
# iteration:51 time consuming: 123.93360710144043
# iteration:52 time consuming: 118.97774243354797
# iteration:53 time consuming: 47.57273602485657
# iteration:54 time consuming: 211.7261667251587
# iteration:55 time consuming: 71.99306130409241
# iteration:56 time consuming: 24.371273517608643
# iteration:57 time consuming: 2.542268753051758
# iteration:58 time consuming: 264.5124316215515
# iteration:59 time consuming: 193.95415687561035
# iteration:60 time consuming: 4.4212586879730225
# iteration:61 time consuming: 178.03314423561096
# iteration:62 time consuming: 285.9381594657898
# iteration:63 time consuming: 291.232134103775
# iteration:64 time consuming: 25.518698692321777
# iteration:65 time consuming: 71.57026958465576
# iteration:66 time consuming: 391.3023314476013
# iteration:67 time consuming: 0.6898980140686035
# iteration:68 time consuming: 114.56137943267822
# iteration:69 time consuming: 32.5324010848999
# iteration:70 time consuming: 16.21524977684021
# iteration:71 time consuming: 40.71237635612488
# iteration:72 time consuming: 26.25245690345764
# iteration:73 time consuming: 216.58356738090515
# iteration:74 time consuming: 300.23034739494324
# iteration:75 time consuming: 4.380505323410034
# iteration:76 time consuming: 122.58328366279602
# iteration:77 time consuming: 6.993711948394775
# iteration:78 time consuming: 179.81038856506348
# iteration:79 time consuming: 60.378469467163086
# iteration:80 time consuming: 1.3101954460144043
# iteration:81 time consuming: 390.69547152519226
# iteration:82 time consuming: 198.93060684204102
# iteration:83 time consuming: 142.1832559108734
# iteration:84 time consuming: 117.09389901161194
# iteration:85 time consuming: 68.12947201728821
# iteration:86 time consuming: 402.98124384880066
# iteration:87 time consuming: 21.35104537010193
# iteration:88 time consuming: 24.099019765853882
# iteration:89 time consuming: 4.062151908874512
# iteration:90 time consuming: 16.237016677856445
# iteration:91 time consuming: 4.829526424407959
# iteration:92 time consuming: 121.37775301933289
# iteration:93 time consuming: 82.35633730888367
# iteration:94 time consuming: 256.5866713523865
# iteration:95 time consuming: 68.83487272262573
# iteration:96 time consuming: 23.324398517608643
# iteration:97 time consuming: 38.84063100814819
# iteration:98 time consuming: 111.78901886940002
# iteration:99 time consuming: 367.26653957366943
# iteration:100 time consuming: 0.6269688606262207
# iteration:101 time consuming: 354.9220631122589
# iteration:102 time consuming: 111.82449579238892
# iteration:103 time consuming: 41.59770679473877
# iteration:104 time consuming: 25.0645534992218
# iteration:105 time consuming: 66.51344394683838
# iteration:106 time consuming: 251.50842595100403
# iteration:107 time consuming: 85.45839715003967
# iteration:108 time consuming: 124.62974119186401
# iteration:109 time consuming: 5.101926803588867
# iteration:110 time consuming: 14.844452619552612
# iteration:111 time consuming: 3.4889864921569824
# iteration:112 time consuming: 27.042717695236206
# iteration:113 time consuming: 21.46692442893982
# iteration:114 time consuming: 412.5435028076172
# iteration:115 time consuming: 68.2385265827179
# iteration:116 time consuming: 125.72341299057007
# iteration:117 time consuming: 140.87927436828613
# iteration:118 time consuming: 205.10842108726501
# iteration:119 time consuming: 410.69247364997864
# iteration:120 time consuming: 2.1663501262664795
# iteration:121 time consuming: 62.95465850830078
# iteration:122 time consuming: 187.94047164916992
# iteration:123 time consuming: 7.298800468444824
# iteration:124 time consuming: 124.9721360206604
# iteration:125 time consuming: 3.1113147735595703
# iteration:126 time consuming: 326.7277400493622
# iteration:127 time consuming: 226.97290587425232
# iteration:128 time consuming: 26.7504665851593
# iteration:129 time consuming: 42.20181655883789
# iteration:130 time consuming: 16.935221433639526
# iteration:131 time consuming: 35.006903409957886
# iteration:132 time consuming: 125.15049409866333
# iteration:133 time consuming: 1.3560311794281006
# iteration:134 time consuming: 408.84161281585693
# iteration:135 time consuming: 67.42529630661011
# iteration:136 time consuming: 25.087291479110718
# iteration:137 time consuming: 317.2443971633911
# iteration:138 time consuming: 299.9149796962738
# iteration:139 time consuming: 186.21701312065125
# iteration:140 time consuming: 4.714111089706421
# iteration:141 time consuming: 205.6265733242035
# iteration:142 time consuming: 281.70247316360474
# iteration:143 time consuming: 2.576519012451172
# iteration:144 time consuming: 24.784460067749023
# iteration:145 time consuming: 69.54891729354858
# iteration:146 time consuming: 239.195654630661
# iteration:147 time consuming: 47.46555781364441
# iteration:148 time consuming: 117.16351747512817
# iteration:149 time consuming: 127.23552179336548
# iteration:150 time consuming: 1.1824650764465332
# iteration:151 time consuming: 109.51032590866089
# iteration:152 time consuming: 25.638411045074463
# iteration:153 time consuming: 10.80383038520813
# iteration:154 time consuming: 354.2788498401642
# iteration:155 time consuming: 71.78408980369568
# iteration:156 time consuming: 118.40494799613953
# iteration:157 time consuming: 439.28005504608154
# iteration:158 time consuming: 216.59362053871155
# iteration:159 time consuming: 65.05422830581665
# iteration:160 time consuming: 1.274857997894287
# iteration:161 time consuming: 79.80953860282898
# iteration:162 time consuming: 428.21893286705017
# iteration:163 time consuming: 31.479299783706665
# iteration:164 time consuming: 131.72889256477356
# iteration:165 time consuming: 75.30396103858948
# iteration:166 time consuming: 149.31299924850464
# iteration:167 time consuming: 421.6971900463104
# iteration:168 time consuming: 26.95249032974243
# iteration:169 time consuming: 294.49532103538513
# iteration:170 time consuming: 16.198901176452637
# iteration:171 time consuming: 276.64087080955505
# iteration:172 time consuming: 126.58526086807251
# iteration:173 time consuming: 60.837135553359985
# iteration:174 time consuming: 406.6078474521637
# iteration:175 time consuming: 2.7608513832092285
# iteration:176 time consuming: 26.145623445510864
# iteration:177 time consuming: 212.87504291534424
# iteration:178 time consuming: 326.8454039096832
# iteration:179 time consuming: 14.620973587036133
# iteration:180 time consuming: 3.5498950481414795
# iteration:181 time consuming: 17.16353940963745
# iteration:182
# ---------------------------------------------------------------------------
# NoConvergence                             Traceback (most recent call last)
# C:\WINDOWS\TEMP/ipykernel_27972/1201331412.py in <module>
# ----> 1 nphi_array,real_spectrum_array,imag_spectrum_array=nH_Hofstadter(mpmath.mpf('0.2'),mpmath.mpf('0')*mpmath.pi)
#
# C:\WINDOWS\TEMP/ipykernel_27972/1024979666.py in nH_Hofstadter(delta, ky, Q, N, dps)
#     215             poly_edge[-1] = poly_edge[-1] + T
#     216             # solve Dk*Dk-Dk*pk+T=0
# --> 217             roots_edge = mpmath.polyroots(poly_edge,maxsteps=1000,extraprec=300)
#     218             # Check whether roots of Dk*Dk-Dk*pk+T satisfy the following condition:
#     219             # Dk=x_+(E), |x_+(E)|<|x_-(E)| or Dk=x_-(E), |x_-(E)|<|x_+(E)|
#
# ~\anaconda3\lib\site-packages\mpmath\calculus\polynomials.py in polyroots(ctx, coeffs, maxsteps, cleanup, extraprec, error, roots_init)
#     194                 err[i] = abs(x)
#     195         if abs(max(err)) >= tol:
# --> 196             raise ctx.NoConvergence("Didn't converge in maxsteps=%d steps." \
#     197                     % maxsteps)
#     198         # Remove small real or imaginary parts
#
# NoConvergence: Didn't converge in maxsteps=1000 steps.

# %%
plt.figure(figsize=(9, 6))

plt.plot(nphi_array, real_spectrum_array, 'b,', markersize=1)
plt.ylabel(r'$\text{Re}(E)$',fontsize=28)
plt.xlabel(r'$p/q$',fontsize=28)
plt.text(0.45,5,r'$\delta=0.2$',fontsize=28)
plt.xticks([0,0.5,1],fontsize=28)
plt.yticks(fontsize=28)
plt.xlim([0,1])
plt.tight_layout()# adjust the fig to avoid cut off in ylabel

#plt.savefig('nH_Hofstadter_Q_150_delta_0_2_ky_0_real.pdf')

plt.show()

# %%
plt.figure(figsize=(9, 6))

plt.plot(nphi_array, imag_spectrum_array, 'r,', markersize=1)
#plt.ylim(-1.1,1.1) # if delta=0
plt.ylabel(r'$\text{Im}(E)$',fontsize=28)
plt.xlabel(r'$p/q$',fontsize=28)
plt.text(0.45,0.85,r'$\delta=0.2$',fontsize=28)
plt.xticks([0,0.5,1],fontsize=28)
plt.yticks([-1,0,1],fontsize=28)
plt.xlim([0,1])
#plt.yticks([-1,-0.5,0,0.5,1],fontsize=20)
plt.tight_layout()# adjust the fig to avoid cut off in ylabel

#plt.savefig('nH_Hofstadter_Q_150_delta_0_2_ky_0_imag.pdf')

plt.show()
